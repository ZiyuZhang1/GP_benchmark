# %% [markdown]
# # Gene Benchmark – End-to-End Run
#
# This notebook loads the unified configuration (defaults: `dga="disgenet"`, `time=2019`, `time_split=True`) and executes the full pipeline.

# %%
from gene_benchmark.config import default_config
from gene_benchmark.pipeline import run_all

cfg = default_config()
cfg

# %% [markdown]
# ## Run pipeline

# %%
run_all(cfg)

# %% [markdown]
# ## Inspect outputs

# %%
import pandas as pd
from pathlib import Path

out_dir = Path(cfg.results_dir)
all_diffusion = out_dir / "diffusion/all_disease.csv"
if all_diffusion.exists():
    display(pd.read_csv(all_diffusion).head())
else:
    print("Run did not produce diffusion results yet.")
